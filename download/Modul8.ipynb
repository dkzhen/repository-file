# %%
# diagram batang (bar plot)

import numpy as np
import matplotlib.pyplot as plt

Usia = [3,12,5,18,45] # numerik
Nama = ('A', 'B', 'C', 'D', 'E') # kategori
pos_y = np.arange(len(Usia)) # reposisi data usia ke array

plt.figure(figsize=(4,3)) # atur ukuran gambar

plt.bar(pos_y, Usia) # data numerik

plt.xticks(pos_y, Nama) # data kategori

plt.xlabel('Nama') # label sumbu x
plt.ylabel('Usia') # label sumbu y

plt.show()

# %%
# data dataframe (Vertikal)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Nama = ['A', 'B', 'C', 'D', 'E']
Usia = [39,63,45,24,13]
df = pd.DataFrame({"Nama" : Nama,
                   "Usia" : Usia})

# atur tema plot dan latar belakang
sns.set(style="darkgrid")

# atur ukuran gambar
plt.figure(figsize=(4,3))

# buat diagram batang
sns.barplot(
x = "Nama",
y = "Usia",
data = df,
estimator = sum)

# menampilkan grafiknya
plt.show()

# %%
# data dataframe (Horizontal)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Nama = ['A', 'B', 'C', 'D', 'E']
Usia = [39,63,45,24,13]
df = pd.DataFrame({"Nama" : Nama,
                   "Usia" : Usia})

# atur tema plot dan latar belakang
sns.set(style="darkgrid")

# atur ukuran gambar
plt.figure(figsize=(4,3))

# buat diagram batang
sns.barplot(
x = "Usia", # posisi x dan y ditukar
y = "Nama",
data = df,
estimator = sum)

# menampilkan grafiknya
plt.show()

# %%
# data dataframe (Vertikal) dengan urut (kecil-besar)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Nama = ['A', 'B', 'C', 'D', 'E']
Usia = [39,63,45,24,13]
df = pd.DataFrame({"Nama" : Nama,
                   "Usia" : Usia})

# susun ulang data frame
df = df.sort_values(["Usia"], ascending=True).reset_index(drop=True)

# atur tema plot dan latar belakang
sns.set(style="darkgrid")

# atur ukuran gambar
plt.figure(figsize=(4,3))

# buat diagram batang
sns.barplot(
x = "Nama",
y = "Usia",
data = df,
estimator = sum)

# menampilkan grafiknya
plt.show()

# %%
# data dataframe (Vertikal) dengan urut (besar-kecil)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Nama = ['A', 'B', 'C', 'D', 'E']
Usia = [39,63,45,24,13]
df = pd.DataFrame({"Nama" : Nama,
                   "Usia" : Usia})

# susun ulang data frame
df = df.sort_values(["Usia"], ascending=False).reset_index(drop=True) # mengganti ascending menjadi false

# atur tema plot dan latar belakang
sns.set(style="darkgrid")

# atur ukuran gambar
plt.figure(figsize=(4,3))

# buat diagram batang
sns.barplot(
x = "Nama",
y = "Usia",
data = df,
estimator = sum)

# menampilkan grafiknya
plt.show()

# %%
# grafik lingkaran (piechart)

import numpy as np
import matplotlib.pyplot as plt

Usia = [3, 12, 5, 18, 45] # data numerik
Nama = ('A', 'B', 'C', 'D', 'E') # data kategori
warna = sns.color_palette('pastel')[0:4] # warna seaborn yang akan digunakan

# atur ukuran gambar
plt.figure(figsize=(7,5))

# membuat diagram lingkaran
plt.pie(
Usia,
labels = Nama,
colors = warna,
autopct = '%.0f%%');

# menampilkan grafiknya
plt.show()

# %%
# grafik peta (TreeMap)

import pandas as pd
import matplotlib.pyplot as plt
import squarify

# buat data dengan data acak
df = pd.DataFrame({'nb_people':[8,3,4,2],
                  'group':['A', 'B', 'C', 'D']})

# atur ukuran gambar
plt.figure(figsize=(4,3))

# membuat diagram
squarify.plot(
    sizes = df['nb_people'],
label = df['group'],
color = ['red','green','blue','grey'],
alpha = .8)

plt.axis('off')

# menampilkan grafiknya
plt.show()

# %%
# data numerik
# grafik histogram

import seaborn as sns
import matplotlib.pyplot as plt

# ukuran gambar
plt.figure(figsize=(4,3))

# latar belakang abu-abu
sns.set_theme(style="darkgrid")
df = sns.load_dataset("iris")

sns.histplot(data = df, x ="sepal_length", bins = 20, kde = True)

plt.show()

# %%
# menampilkan 5 data pertama

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# menampilkan 5 data terakhir

df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# menampilkan dua variabel dalam 1 grafik

import seaborn as sns
import matplotlib.pyplot as plt

# atur ukuran gambar
plt.figure(figsize=(4,3))

# atur latar belakang abu-abu
sns.set_theme(style="darkgrid")
df = sns.load_dataset("iris")

sns.histplot(data = df, x = "sepal_length", color = "skyblue", label = "Sepal Length", kde = True)

sns.histplot(data = df, x = "sepal_width", color = "red", label = "Sepal Width", kde = True)

# menampilkan grafiknya
plt.legend()

plt.show()

# %%
# membagi beberapa histogram

import seaborn as sns
import matplotlib.pyplot as plt

# atur latar belakang abu-abu
sns.set_theme(style="darkgrid")
df = sns.load_dataset("iris")

# membagi grafik 2 kali 2
fig,axs = plt.subplots(2,2, figsize=(8,6))

sns.histplot(data = df, x = "sepal_length", color = "skyblue", kde = True, ax = axs[0,0])

sns.histplot(data = df, x = "sepal_length", color = "olive", kde = True, ax = axs[0,1])

sns.histplot(data = df, x = "sepal_length", color = "tomato", kde = True, ax = axs[1,0])

sns.histplot(data = df, x = "sepal_length", color = "gold", kde = True, ax = axs[1,1])

plt.show()

# %%
# grafik kepadatan kernel
import seaborn as sns
import matplotlib.pyplot as plt

# atur latar belakang abu-abu
sns.set_theme(style="darkgrid")
df = sns.load_dataset("iris")

# membagi grafik 2 kali 2
fig, axs = plt.subplots(2, 2, figsize=(7, 7))

sns.kdeplot(data=df, x="sepal_length", color="skyblue", fill=True, ax=axs[0, 0])

sns.kdeplot(data=df, x="sepal_width", color="olive", fill=True, ax=axs[0, 1])

sns.kdeplot(data=df, x="petal_length", color="gold", fill=True, ax=axs[1, 0])

sns.kdeplot(data=df, x="petal_width", color="teal", fill=True, ax=axs[1, 1])

plt.show()

# %%
# tumpang tindih dengan transparansi
import seaborn as sns
import matplotlib.pyplot as plt
from plotnine.data import diamonds

# tetapkan ukuran gambar untuk notebook
plt.rcParams["figure.figsize"]=8, 6

# atur tema whitegrid seaborn
sns.set(style="whitegrid")

# tanpa transparansi
sns.kdeplot(data = diamonds,
           x = "price",
           hue = "cut",
           cut = 0,
           fill = True,
           common_norm = False,
           alpha = 0.4) # penyesuaian nilai transparansi dengan alpha

plt.show()

# %%
# grafik bertingkat
import seaborn as sns
import matplotlib.pyplot as plt
from plotnine.data import diamonds

# atur ukuran gambar
plt.figure(figsize=(8,6))

# atur tema whitegrid seaborn
sns.set(style="whitegrid")

# plot kepadatan bertumpuk
sns.kdeplot(data = diamonds,
           x = "price",
           hue = "cut",
           common_norm = False,
           multiple = "fill",
           alpha = 0.7)

plt.show()

# %%
# grafik lolipop
# membuat dataframe
import numpy as np
import pandas as pd
df = pd.DataFrame({'group':list(map(chr, range(65, 85))),
                  'values':np.random.uniform(size=20)})

# mengurutkan berdasarkan nilai
ordered_df = df.sort_values(by='values')
my_range=range(1,len(df.index)+1)

# ukuran gambar
plt.figure(figsize=(8, 6))

# tema whitegrid seaborn
sns.set(style="whitegrid")

# buat plotnya
plt.stem(ordered_df['values'])
plt.xticks(my_range, ordered_df['group'])
plt.show()

# %%
# tanpa garis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'group':list(map(chr, range(65, 85))),
                  'values':np.random.uniform(size=20)})

# mengurutkan berdasarkan nilai
ordered_df = df.sort_values(by='values')
my_range=range(1,len(df.index)+1)

# buat warna jika grupnya adalah "B"
my_color=np.where(ordered_df ['group']=='B', 'orange', 'skyblue')
my_size=np.where(ordered_df ['group']=='B', 70, 30)

# ukuran gambar
plt.figure(figsize=(8, 6))

# tema whitegrid seaborn
sns.set(style="whitegrid")

# plot horizontal dibuat menggunakan funsi hline()
plt.hlines(y = my_range,
          xmin = 0,
          xmax = ordered_df['values'],
          color = my_color,
          alpha = 0.48)

plt.scatter(ordered_df['values'],
           my_range,
           color = my_color,
           s = my_size,
           alpha = 1)

# tambahkan judul dan nama sumbu
plt.yticks(my_range, ordered_df['group'])
plt.title("Fokus dengan Grup B", loc='left')
plt.xlabel('Nilai Variabel')
plt.ylabel('Grup')
plt.show()

# %%
# bivariat(dua variabel)
# boxplot
import seaborn as sns               # import perpustakaan seaborn
from warnings import filterwarnings # untuk menghindari peringatan
df = sns.load_dataset('tips')       # memuat dataset dari seaborn

# atur ukuran gambar
plt.figure(figsize=(8, 6))

# atur tema whitegrid seaborn
sns.set(style="whitegrid")

# membuat grafik boxplotnya
sns.boxplot(x = 'day',
           y = 'total_bill',
           data = df,
           hue = 'smoker')

# menampilkan grafiknya
plt.show()

# %%
# grafik biola (violinplot)
import seaborn as sns
from warnings import filterwarnings
import matplotlib.pyplot as plt
df = sns.load_dataset('tips') # memuat dataset dari seaborn

# atur ukuran gambar
plt.figure(figsize=(8, 6))

# atur tema whitegrid seaborn
sns.set(style="whitegrid")

# grouped violinplot
sns.violinplot(x = "day",
              y = "total_bill",
              hue = "smoker",
              data = df,
              palette = "Pastel1")

plt.show()

# %%
# numerik vs numerik
# plot pencar
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# atur ukuran gambar
plt.figure(figsize=(8, 6))

# atur tema whitegrid seaborn
sns.set(style="whitegrid")

df = pd.DataFrame({'x_values': range(1,101),
                  'y_values': np.random.randn(100)*15+range(1,101)})

plt.plot('x_values',
        'y_values',
        data = df,
        linestyle = 'none',
        marker = 'o')

# menambahkan label
plt.xlabel('Permintaan')
plt.ylabel('Penawaran')
plt.show()

# %%
# grafik garis
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# atur ukuran gambar
plt.figure(figsize=(8, 6))

# atur tema whitegrid seaborn
sns.set(style="whitegrid")

df = pd.DataFrame({'x_values': range(1,101),
                  'y_values': np.random.randn(100)*15+range(1,101)})

plt.plot('x_values',
        'y_values',
        data = df)

# menambahkan label
plt.xlabel('Permintaan')
plt.ylabel('Penawaran')
plt.show()

# %%
# multi variat(multi variabel)
# grafik scatter dan grup
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('iris')

# atur ukuran gambar
plt.figure(figsize=(8, 6))

# atur tema whitegrid seaborn
sns.set(style="whitegrid")

# gunakan argumen 'hue' untuk menambahkan variabel faktor
sns.lmplot(x = "sepal_length",
          y = "sepal_width",
          data = df,
          fit_reg = False,
          hue = 'species',
          legend = False,
          markers=["o", "x", "1"])

# pindahkan legend ke bagian plot yang kosong
plt.legend(loc='lower right')

plt.show()

# %%
# grafik korelogram
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('iris')

# memuat grafik korelogram
sns.pairplot(df,
            kind = "scatter",
            hue = "species",
            markers = ["o", "s", "D"],
            palette = "Set2")

plt.show()

# %%
# grafik berlapis (faceting)
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

my_count=["France","Australia","Japan","USA","Germany",
          "Congo","China","England","Spain","Greece",
         "Maroco","South Africa","Indonesia","Peru",
         "Chili","Brazil"]

df = pd.DataFrame({"country":np.repeat(my_count, 10),
                  "years":list(range(2000, 2010)) * 16,
                  "value":np.random.rand(160)})

# inisialisasi grafik berlapis
g = sns.FacetGrid(df, col='country', hue='country', col_wrap=4)

# tambahkan garis diatas area dengan fungsi plot
g = g.map(plt.plot, 'years', 'value')

# isi area dengan fill between
g = g.map(plt.fill_between,
         'years',
         'value',
         alpha = 0.2).set_titles("{col_name} country")

# pengaturan nama variabel setiap aspek
g = g.set_titles("{col_name}")

# tambahkan nama variabel untuk keseluruhan plot
plt.subplots_adjust(top=0.92)
g = g.fig.suptitle('Evolusi harga suatu produk di 16 negara')

plt.show()

# %%
# TUGAS
# No 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('D:\Kuliah STMIK\Semester4\Big Data\Data\data_soal_1.csv')
df
# Out:
#     ID Pelanggan     Nama  Jenis Kelamin  Pendapatan Produk   Harga  Jumlah  \
# 0              1     Arif              1      600000      A  100000       4
# 1              2     Dian              2     1200000      D  250000       4
# 2              3    Dinda              2      950000      D  250000       3
# 3              4    Fajar              1      400000      A  100000       2
# 4              5      Ika              2     1200000      D  250000       4
# 5              6    Ilham              1      800000      B  150000       4
# 6              7    Indra              1      950000      B  150000       5
# 7              8  Kartika              2     1100000      E  300000       3
# 8              9  Lestari              2      800000      E  300000       2
# 9             10      Lia              2     1700000      E  300000       5
# 10            11    Maria              2      600000      A  100000       4
# 11            12     Maya              2      950000      B  150000       5
# 12            13     Mila              2      400000      C  200000       1
# 13            14    Nurul              2     6450000      D  250000       5
# 14            15    Retno              2     1000000      C  200000       4
#
#       Total
# 0    400000
# 1   1000000
# 2    750000
# 3    200000
# 4   1000000
# 5    600000
# 6    750000
# 7    900000
# 8    600000
# 9   1500000
# 10   400000
# 11   750000
# 12   200000
# 13  1250000
# 14   800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID Pelanggan   15 non-null     int64
#  1   Nama           15 non-null     object
#  2   Jenis Kelamin  15 non-null     int64
#  3   Pendapatan     15 non-null     int64
#  4   Produk         15 non-null     object
#  5   Harga          15 non-null     int64
#  6   Jumlah         15 non-null     int64
#  7   Total          15 non-null     int64
# dtypes: int64(6), object(2)
# memory usage: 1.1+ KB

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# atur ukuran gambar
plt.figure(figsize=(8, 6))

# atur tema whitegrid seaborn
sns.set(style="whitegrid")

plt.plot('Pendapatan',
        'Total',
        data = df,
        linestyle = 'none',
        marker = 'o')

# menambahkan label
plt.xlabel('Pendapatan')
plt.ylabel('Total')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('D:\Kuliah STMIK\Semester4\Big Data\Data\data_soal_1.csv')

pendapatan = df['Pendapatan(ribu)']
nama = df['Nama']
pos_y = np.arange(len(pendapatan))

plt.figure(figsize=(10,3))

plt.bar(pos_y, pendapatan)

plt.xticks(pos_y, nama)

plt.xlabel('Nama')
plt.ylabel('Pendapatan(ribu)')

plt.show()
